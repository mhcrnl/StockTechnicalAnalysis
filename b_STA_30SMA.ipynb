# %% [markdown]
# # Stock Technical Analysis: Python Tutorial

# %%
# ON LINUX Call a bash script
import subprocess
subprocess.call(['./gitpush.sh'])
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-25-2cdf87142f38> in <module>
#       1 import subprocess
#       2
# ----> 3 subprocess.call(['./gitpush.sh'])
#
# C:\ProgramData\Anaconda3\lib\subprocess.py in call(timeout, *popenargs, **kwargs)
#     321     retcode = call(["ls", "-l"])
#     322     """
# --> 323     with Popen(*popenargs, **kwargs) as p:
#     324         try:
#     325             return p.wait(timeout=timeout)
#
# C:\ProgramData\Anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     773                                 c2pread, c2pwrite,
#     774                                 errread, errwrite,
# ...

# %% [markdown]
# ## Update: 25/04/2020

# %% [markdown]
# Plot 30 Day Simple Moving Average
#
# Contact: andrewshamlet@gmail.com // @andrewshamlet

# %% [markdown]
# Last tutorial we learned to query and plot daily close data.

# %% [markdown]
# In this lesson, we will calculate the 30 day simple moving average.

# %% [markdown]
# What is a simple moving average?

# %% [markdown]
# A simple moving average is customizable in that it can be calculated for a different number of time periods, simply by adding the closing price of the security for a number of time periods and then dividing this total by the number of time periods, which gives the average price of the security over the time period. A simple moving average smoothes out volatility, and makes it easier to view the price trend of a security. If the simple moving average points up, this means that the security's price is increasing. If it is pointing down it means that the security's price is decreasing. The longer the timeframe for the moving average, the smoother the simple moving average. A shorter-term moving average is more volatile, but its reading is closer to the source data.

# %% [markdown]
# Let’s use Python to compute the 30 day simple moving average.

# %% [markdown]
# 1.) Code from last tutorial.

# %%
import pandas as pd
print(pd.__version__)
import datetime
import pandas_datareader as pdr
import matplotlib.pyplot as plt
# %matplotlib inline

stocks = ['FB']
start = datetime.datetime(2016, 1, 1)
end = datetime.date.today()

def get_stock(stock,start,end):
     return pdr.DataReader(stock,'yahoo',start,end)['Close']
df = pd.DataFrame({n: get_stock(n, start, end) for n in stocks})
df.tail()
# Out:
# 0.25.1
#                     FB
# Date
# 2020-04-20  178.240005
# 2020-04-21  170.800003
# 2020-04-22  182.279999
# 2020-04-23  185.130005
# 2020-04-24  190.070007

# %% [markdown]
# 2.) Calculate the 30 day simple moving average.

# %%
df.rolling(window=30).mean()
# Out:
#                     FB
# Date
# 2016-01-04         NaN
# 2016-01-05         NaN
# 2016-01-06         NaN
# 2016-01-07         NaN
# 2016-01-08         NaN
# ...                ...
# 2020-04-20  164.186001
# 2020-04-21  164.229334
# 2020-04-22  164.365667
# 2020-04-23  164.862001
# 2020-04-24  166.048667
#
# [1085 rows x 1 columns]

# %% [markdown]
# 3.) Call the plot function.

# %%
df.plot(figsize=(20, 5))

# %% [markdown]
# There you have it! We calculated and plotted the 30 day simple moving average along with the daily close. Looks like the stock tanked towards the end of 2016, perhaps due to the US Presidential Election 😉

# %% [markdown]
# Here is the full code:

# %%
import pandas as pd
import pandas_datareader as pdr
import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

stocks = ['FB']
start = datetime.datetime(2019, 1, 1)
end = datetime.date.today()

def get_stock(stock,start,end):
     return pdr.DataReader(stock,'yahoo',start,end)['Close']
df = pd.DataFrame({n: get_stock(n, start, end) for n in stocks})
df['30 mavg'] = df.rolling(window=30).mean()
df.plot(figsize=(20, 5))

# %%
from IPython.core.display import display, HTML
display(HTML("""<a href=mhcrnl@gmail.com>EMAIL: mhcrnl@gmail.com</a>"""))
display(HTML("""<a href=https://www.instagram.com/mhcrnl>Instagram: @mhcrnl</a>"""))
# Out:
# <a href=mhcrnl@gmail.com>EMAIL: mhcrnl@gmail.com</a>
# <a href=https://www.instagram.com/mhcrnl>Instagram: @mhcrnl</a>

# %%
# %pastebin '01_tesla.ipynb'
# Out:
# 'http://dpaste.com/0N3ZQG2'

# %%
# %%HTML
# <img src="https://blog.dominodatalab.com/wp-content/uploads/2016/05/Screen-Shot-2015-11-02-at-10-20-38-PM.png">
# Out:
# <img src="https://blog.dominodatalab.com/wp-content/uploads/2016/05/Screen-Shot-2015-11-02-at-10-20-38-PM.png">

# %%
import folium
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-30-173c1173bf1c> in <module>
# ----> 1 import folium
#
# ModuleNotFoundError: No module named 'folium'
